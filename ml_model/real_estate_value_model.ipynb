# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/home/timur/HM_course/HM3/all_v2.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5477006 entries, 0 to 5477005
# Data columns (total 13 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   price          int64
#  1   date           object
#  2   time           object
#  3   geo_lat        float64
#  4   geo_lon        float64
#  5   region         int64
#  6   building_type  int64
#  7   level          int64
#  8   levels         int64
#  9   rooms          int64
#  10  area           float64
#  11  kitchen_area   float64
#  12  object_type    int64
# dtypes: float64(4), int64(7), object(2)
# memory usage: 543.2+ MB

# %%
data.drop(['building_type', 'date', 'time', 'geo_lon', 'geo_lat', 'object_type'], axis= 1 , inplace= True )

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
data = data.loc[data['price'] > 100000]
data = data.loc[data['region'] <= 85]
data = data.loc[data['price'] < 1000000000]
data = data.sample(frac=0.25)

# %%
data['price'].count()
# Out:
# 234828

# %%
X = data.drop('price', axis=1)
y = data['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
rf = RandomForestRegressor()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(X_test, y_test)
# Out:
# 0.6964370434077836

# %%
rf.predict(np.array([77, 15, 15, 4, 130, 20]).reshape(1, -1))
# Out:
# /home/timur/.cache/pypoetry/virtualenvs/homeworkproject-hN4QtuxE-py3.10/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([11247906.09])

# %%
np.array([39, 4, 5, 2, 32, 6]).reshape(-1, 1)
# Out:
# array([[39],
#        [ 4],
#        [ 5],
#        [ 2],
#        [32],
#        [ 6]])

# %%
import joblib

# Save to file in the current working directory
joblib_file = "joblib_model.pkl"
joblib.dump(rf, joblib_file)
# Out:
# ['joblib_model.pkl']

# %%
rf.predict(pd.Series([77, 15, 15, 4, 130, 20], ['region', 'level', 'levels', 'rooms', 'area', 'kitchen_area']))
# Out:
# /home/timur/.cache/pypoetry/virtualenvs/homeworkproject-hN4QtuxE-py3.10/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 rf.predict(pd.Series([77, 15, 15, 4, 130, 20], ['region', 'level', 'levels', 'rooms', 'area', 'kitchen_area']))
#
# File ~/.cache/pypoetry/virtualenvs/homeworkproject-hN4QtuxE-py3.10/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:981, in ForestRegressor.predict(self, X)
#     979 check_is_fitted(self)
#     980 # Check data
# --> 981 X = self._validate_X_predict(X)
#     983 # Assign chunk of trees to jobs
#     984 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# ...

# %%
d = {'region': 39, 'level': 3, 'levels': 5, 'rooms': 2, 'area': 50.0, 'kitchen_area': 10.0}
pd.DataFrame(data=d, index=[0])

# %%
X_test
